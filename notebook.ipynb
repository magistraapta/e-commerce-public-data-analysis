# %% [markdown]
# # **Dicoding Submission**
# E-commerce Public Dataset
#
# Nama: Muhammad Magistra Apta Paramarta
# Email: magistraagis@gmail.com
# ID Dicoding: magistra_apta

# %% [markdown]
# # Define Question
#
# 1. What is the most selling product?
# 2. How successful the delivery?
# 3. What location with the most customer?

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# # **Data Wrangling**

# %% [markdown]
# ### **Product**

# %%
product = pd.read_csv('datasets/products_dataset.csv')
product.head(5)
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0

# %%
category = pd.read_csv('datasets/product_category_name_translation.csv')
product.head(5)
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0

# %% [markdown]
# ### **Customers**

# %%
customer = pd.read_csv('datasets/customers_dataset.csv')
customer.head(5)
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %% [markdown]
# ### **Geolocation**

# %% [markdown]
# Read geolocation dataset

# %%
geolocation = pd.read_csv('datasets/geolocation_dataset.csv')
geolocation.head(5)
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %% [markdown]
# ### **Orders**

# %% [markdown]
# Read orders dataset

# %%
orders = pd.read_csv('datasets/orders_dataset.csv')
orders.head(5)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00
# 3           2017-12-15 00:00:00
# 4           2018-02-26 00:00:00

# %% [markdown]
# Read order items dataset

# %%
order_items_df = pd.read_csv('datasets/order_items_dataset.csv')
order_items_df.head(5)
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14

# %% [markdown]
# Read order payments dataset

# %%
order_payments_df = pd.read_csv('datasets/order_payments_dataset.csv')
order_payments_df.head(5)
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %% [markdown]
# Read order reviews dataset

# %%
order_reviews_df = pd.read_csv('datasets/order_reviews_dataset.csv')
order_reviews_df.head(5)
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# 3              Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4  Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24
# 3     2017-04-21 22:02:06
# 4     2018-03-02 10:26:53

# %% [markdown]
# ### **Sellers**

# %% [markdown]
# Read sellers dataset

# %%
sellers = pd.read_csv('datasets/sellers_dataset.csv')
sellers.head(5)
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# ### **Assesing Data**

# %% [markdown]
# Read info of the data

# %%
product.info()
geolocation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %%
order_items_df.info()
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
order_payments_df.info()
order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
orders.info()
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
customer.info()
sellers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %% [markdown]
# check missing value

# %%
customer.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
geolocation.isna().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
order_items_df.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
order_payments_df.isna().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
order_reviews_df.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
orders.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
product.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
sellers.isna().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %% [markdown]
# check duplicated data

# %%
datasets = [customer, geolocation, orders, order_items_df, order_payments_df, order_reviews_df, product, sellers]

for dataset in datasets:
    
    print(f'total duplicates: {dataset.duplicated().sum()}\n')

## only geolocation has duplicates
# Out:
# total duplicates: 0
# total duplicates: 261831
#
# total duplicates: 0
#
# total duplicates: 0
#
# total duplicates: 0
#
# total duplicates: 0
#
# total duplicates: 0
#
# total duplicates: 0

# %% [markdown]
# Desribe the data

# %%
customer.describe(include='all')
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# count               99441.000000         99441          99441
# unique                       NaN          4119             27
# top                          NaN     sao paulo             SP
# freq                         NaN         15540          41746
# mean                35137.474583           NaN            NaN
# std                 29797.938996           NaN            NaN
# min                  1003.000000           NaN            NaN
# 25%                 11347.000000           NaN            NaN
# 50%                 24416.000000           NaN            NaN
# 75%                 58900.000000           NaN            NaN
# max                 99990.000000           NaN            NaN

# %%
geolocation.describe()
# Out:
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# count                 1.000163e+06     1.000163e+06     1.000163e+06
# mean                  3.657417e+04    -2.117615e+01    -4.639054e+01
# std                   3.054934e+04     5.715866e+00     4.269748e+00
# min                   1.001000e+03    -3.660537e+01    -1.014668e+02
# 25%                   1.107500e+04    -2.360355e+01    -4.857317e+01
# 50%                   2.653000e+04    -2.291938e+01    -4.663788e+01
# 75%                   6.350400e+04    -1.997962e+01    -4.376771e+01
# max                   9.999000e+04     4.506593e+01     1.211054e+02

# %%
order_items_df.describe()
# Out:
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %%
order_payments_df.describe()
# Out:
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %%
order_reviews_df.describe(include='all')
# Out:
#                                review_id                          order_id  \
# count                              99224                             99224
# unique                             98410                             98673
# top     7b606b0d57b078384f0b58eac1d41d78  c88b1d1b157a9999ce368f218a407141
# freq                                   3                                 3
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         review_score review_comment_title review_comment_message  \
# count   99224.000000                11568                  40977
# unique           NaN                 4527                  36159
# top              NaN            Recomendo              Muito bom
# freq             NaN                  423                    230
# mean        4.086421                  NaN                    NaN
# std         1.347579                  NaN                    NaN
# min         1.000000                  NaN                    NaN
# 25%         4.000000                  NaN                    NaN
# 50%         5.000000                  NaN                    NaN
# 75%         5.000000                  NaN                    NaN
# max         5.000000                  NaN                    NaN
#
#        review_creation_date review_answer_timestamp
# count                 99224                   99224
# unique                  636                   98248
# top     2017-12-19 00:00:00     2017-06-15 23:21:05
# freq                    463                       4
# mean                    NaN                     NaN
# std                     NaN                     NaN
# min                     NaN                     NaN
# 25%                     NaN                     NaN
# 50%                     NaN                     NaN
# 75%                     NaN                     NaN
# max                     NaN                     NaN

# %%
orders.describe()
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-04-11 10:48:14  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# top             2018-05-09 15:48:00           2018-05-08 23:38:46
# freq                             47                             3
#
#        order_estimated_delivery_date
# count                          99441
# unique                           459
# top              2017-12-20 00:00:00
# freq                             522

# %%
product.describe()
# Out:
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# min            0.000000           7.000000           2.000000
# 25%          300.000000          18.000000           8.000000
# 50%          700.000000          25.000000          13.000000
# 75%         1900.000000          38.000000          21.000000
# max        40425.000000         105.000000         105.000000
#
#        product_width_cm
# count      32949.000000
# mean          23.196728
# std           12.079047
# min            6.000000
# 25%           15.000000
# 50%           20.000000
# 75%           30.000000
# max          118.000000

# %%
sellers.describe()
# Out:
#        seller_zip_code_prefix
# count             3095.000000
# mean             32291.059451
# std              32713.453830
# min               1001.000000
# 25%               7093.500000
# 50%              14940.000000
# 75%              64552.500000
# max              99730.000000

# %% [markdown]
# ### **Cleaning Data**

# %% [markdown]
# delete duplicates from geolocation datasets

# %%
geolocation.duplicated().sum()
# Out:
# 261831

# %%
geolocation.drop_duplicates(inplace=True)
geolocation.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Change the datetime data type from objc to date-time

# %%
orders_col = [
    'order_purchase_timestamp',
    'order_approved_at',
    'order_delivered_carrier_date',
    'order_delivered_customer_date',
    'order_estimated_delivery_date'
    ]

for col in orders_col:
    orders[col] = pd.to_datetime(orders[col])

orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %%
order_reviews_col = [
    'review_creation_date',
    'review_answer_timestamp'
]

for col in order_reviews_col:
    order_reviews_df[col] = pd.to_datetime(order_reviews_df[col])

order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  datetime64[ns]
#  6   review_answer_timestamp  99224 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 5.3+ MB

# %%
order_items_col = ['shipping_limit_date']

for col in order_items_col:
    order_items_df[col] = pd.to_datetime(order_items_df[col])
    
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %% [markdown]
# Handle the missing value

# %%
## change the missing value for title and message review
order_reviews_df['review_comment_title'].fillna('No Title')
order_reviews_df['review_comment_message'].fillna('No Message')
# Out:
# 0                                               No Message
# 1                                               No Message
# 2                                               No Message
# 3                    Recebi bem antes do prazo estipulado.
# 4        Parabéns lojas lannister adorei comprar pela I...
#                                ...
# 99219                                           No Message
# 99220                                           No Message
# 99221    Excelente mochila, entrega super rápida. Super...
# 99222                                           No Message
# 99223    meu produto chegou e ja tenho que devolver, po...
# Name: review_comment_message, Length: 99224, dtype: object

# %%
order_reviews_df.head(5)
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4             No Title
# 1             5             No Title
# 2             5             No Title
# 3             5             No Title
# 4             5             No Title
#
#                               review_comment_message review_creation_date  \
# 0                                         No Message           2018-01-18
# 1                                         No Message           2018-03-10
# 2                                         No Message           2018-02-17
# 3              Recebi bem antes do prazo estipulado.           2017-04-21
# 4  Parabéns lojas lannister adorei comprar pela I...           2018-03-01
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24
# 3     2017-04-21 22:02:06
# 4     2018-03-02 10:26:53

# %% [markdown]
# Drop unused cols on product table

# %%
product_drop_cols = [
    'product_name_lenght',
    'product_description_lenght',
    'product_weight_g',
    'product_length_cm',
    'product_height_cm',
    'product_width_cm'
]

product.drop(product_drop_cols, axis=1, inplace=True)

# %% [markdown]
# ## **Exploratory Data Analysis**

# %% [markdown]
# Explore customer & order

# %%
customer_order_df = pd.merge(
    left=customer,
    right=orders,
    how='left',
    left_on='customer_id',
    right_on='customer_id'
)

customer_order_df.head(5)
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# 0  00e7ee1b050b8499577073aeb2a297a1    delivered      2017-05-16 15:05:35
# 1  29150127e6685892b6eab3eec79f59c7    delivered      2018-01-12 20:48:24
# 2  b2059ed67ce144a36e2aa97d2c9e9ad2    delivered      2018-05-19 16:07:45
# 3  951670f92359f4fe4a63112aa7306eba    delivered      2018-03-13 16:06:38
# 4  6b7d50bd145f6fc7f33cebabd7e49d0f    delivered      2018-07-29 09:51:30
#
#     order_approved_at order_delivered_carrier_date  \
# 0 2017-05-16 15:22:12          2017-05-23 10:47:57
# 1 2018-01-12 20:58:32          2018-01-15 17:14:59
# 2 2018-05-20 16:19:10          2018-06-11 14:31:00
# 3 2018-03-13 17:29:19          2018-03-27 23:22:42
# 4 2018-07-29 10:10:09          2018-07-30 15:16:00
#
#   order_delivered_customer_date order_estimated_delivery_date
# 0           2017-05-25 10:35:35                    2017-06-05
# 1           2018-01-29 12:41:19                    2018-02-06
# 2           2018-06-14 17:58:51                    2018-06-13
# 3           2018-03-28 16:04:25                    2018-04-10
# 4           2018-08-09 20:55:48                    2018-08-15

# %% [markdown]
# Explore payment & reviews

# %%
payments_reviews_df = pd.merge(
    left=order_payments_df,
    right=order_reviews_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)

payments_reviews_df.head(5)
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
#
#    payment_installments  payment_value                         review_id  \
# 0                     8          99.33  4ce650e117a5b292bf5ea980a61eb61e
# 1                     1          24.39  ad2036caca61484fc435d7e673c020f2
# 2                     1          65.71  bcddfa0f7d2e54cfc74bae4f01b84d92
# 3                     8         107.78  c37a0e51e5df82bdb55d38ff0ffb6af3
# 4                     8         107.78  5bc7680443b4ef765fec11a8201eeb0c
#
#    review_score review_comment_title  \
# 0           1.0        Não recomendo
# 1           5.0             No Title
# 2           5.0             No Title
# 3           5.0             No Title
# 4           5.0             No Title
#
#                               review_comment_message review_creation_date  \
# 0  Produto com qualidade ruim, amassado e descasc...           2018-05-10
# 1                                         No Message           2018-06-30
# 2                                           Aprovada           2017-12-19
# 3                                         No Message           2017-12-21
# 4                                         No Message           2017-12-21
#
#   review_answer_timestamp
# 0     2018-05-15 23:38:00
# 1     2018-07-03 11:23:16
# 2     2017-12-22 17:55:30
# 3     2017-12-21 21:42:31
# 4     2017-12-22 01:10:39

# %%
payments_reviews_df.groupby(by='payment_type').order_id.nunique().sort_values(ascending=False)
# Out:
# payment_type
# credit_card    76505
# boleto         19784
# voucher         3866
# debit_card      1528
# not_defined        3
# Name: order_id, dtype: int64

# %% [markdown]
# Explore item & seller

# %%
seller_item_df = pd.merge(
    left=order_items_df,
    right=sellers,
    how='left',
    left_on='seller_id',
    right_on='seller_id'
)

seller_item_df.head(5)
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  seller_zip_code_prefix  \
# 0 2017-09-19 09:45:35   58.90          13.29                   27277
# 1 2017-05-03 11:05:13  239.90          19.93                    3471
# 2 2018-01-18 14:48:30  199.00          17.87                   37564
# 3 2018-08-15 10:10:18   12.99          12.79                   14403
# 4 2017-02-13 13:57:51  199.90          18.14                   87900
#
#      seller_city seller_state
# 0  volta redonda           SP
# 1      sao paulo           SP
# 2  borda da mata           MG
# 3         franca           SP
# 4         loanda           PR

# %% [markdown]
# Explore product & category

# %%
product_category_df = pd.merge(
    left=product,
    right=category,
    how='left',
    left_on='product_category_name',
    right_on='product_category_name'
)

product_category_df.head(5)
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_photos_qty product_category_name_english
# 0                 1.0                     perfumery
# 1                 1.0                           art
# 2                 1.0                sports_leisure
# 3                 1.0                          baby
# 4                 4.0                    housewares

# %% [markdown]
# explore product category with the most quantity

# %%
product_category_df.groupby(by='product_category_name_english').product_id.nunique().sort_values(ascending=False).head(10)
# Out:
# product_category_name_english
# bed_bath_table           3029
# sports_leisure           2867
# furniture_decor          2657
# health_beauty            2444
# housewares               2335
# auto                     1900
# computers_accessories    1639
# toys                     1411
# watches_gifts            1329
# telephony                1134
# Name: product_id, dtype: int64

# %% [markdown]
# Explore seller & product_category

# %%
seller_product_df = pd.merge(
    left=product_category_df,
    right=seller_item_df,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
seller_product_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_photos_qty product_category_name_english  \
# 0                 1.0                     perfumery
# 1                 1.0                           art
# 2                 1.0                sports_leisure
# 3                 1.0                          baby
# 4                 4.0                    housewares
#
#                            order_id  order_item_id  \
# 0  e17e4f88e31525f7deef66779844ddce              1
# 1  5236307716393b7114b53ee991f36956              1
# 2  01f66e58769f84129811d43eefd187fb              1
# 3  143d00a4f2dde4e0364ee1821577adb3              1
# 4  86cafb8794cb99a9b1b77fc8e48fbbbb              1
#
#                           seller_id shipping_limit_date   price  \
# 0  5670f4db5b62c43d542e1b2d56b0cf7c 2018-04-30 17:33:54   10.91
# 1  b561927807645834b59ef0d16ba55a24 2018-02-06 19:11:15  248.00
# 2  7b07b3c7487f0ea825fc6df75abd658b 2018-07-11 21:30:20   79.80
# 3  c510bc1718f0f2961eaa42a23330681a 2018-08-07 09:10:13  112.30
# 4  0be8ff43f22e456b4e0371b2245e4d01 2018-04-17 01:30:23   37.90
#
#    freight_value  seller_zip_code_prefix seller_city seller_state
# 0           7.39                    3694   sao paulo           SP
# 1          17.99                    2955   sao paulo           SP
# 2           7.82                    2016   sao paulo           SP
# 3           9.54                   13330  indaiatuba           SP
# 4           8.29                    4461   sao paulo           SP

# %% [markdown]
# we can see the most expensive product comes from health_beauty category

# %%
seller_product_df.groupby(by='product_category_name_english').price.nunique().sort_values(ascending=False)
# Out:
# product_category_name_english
# health_beauty                        1263
# sports_leisure                       1139
# housewares                           1110
# computers_accessories                1003
# bed_bath_table                        871
#                                      ...
# furniture_mattress_and_upholstery       9
# home_comfort_2                          5
# fashion_childrens_clothes               4
# security_and_services                   2
# cds_dvds_musicals                       2
# Name: price, Length: 71, dtype: int64

# %%
all_df = pd.merge(
    left=customer_df,
    right=seller_product_df,
    how='left',
    left_on='order_id',
    right_on='order_id'
)

all_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 2  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 3  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 4  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
#
#    customer_zip_code_prefix customer_city customer_state  \
# 0                     14409        franca             SP
# 1                     14409        franca             SP
# 2                     14409        franca             SP
# 3                     14409        franca             SP
# 4                     14409        franca             SP
#
#                            order_id order_status order_purchase_timestamp  \
# 0  00e7ee1b050b8499577073aeb2a297a1    delivered      2017-05-16 15:05:35
# 1  00e7ee1b050b8499577073aeb2a297a1    delivered      2017-05-16 15:05:35
# 2  00e7ee1b050b8499577073aeb2a297a1    delivered      2017-05-16 15:05:35
# 3  00e7ee1b050b8499577073aeb2a297a1    delivered      2017-05-16 15:05:35
# 4  00e7ee1b050b8499577073aeb2a297a1    delivered      2017-05-16 15:05:35
#
#     order_approved_at order_delivered_carrier_date  ... product_photos_qty  \
# 0 2017-05-16 15:22:12          2017-05-23 10:47:57  ...                1.0
# 1 2017-05-16 15:22:12          2017-05-23 10:47:57  ...                1.0
# 2 2017-05-16 15:22:12          2017-05-23 10:47:57  ...                1.0
# 3 2017-05-16 15:22:12          2017-05-23 10:47:57  ...                1.0
# 4 2017-05-16 15:22:12          2017-05-23 10:47:57  ...                1.0
#
#   product_category_name_english  order_item_id  \
# 0              office_furniture            1.0
# 1              office_furniture            1.0
# 2              office_furniture            1.0
# 3              office_furniture            1.0
# 4              office_furniture            1.0
#
#                           seller_id  shipping_limit_date   price  \
# 0  7c67e1448b00f6e969d365cea6b010ab  2017-05-22 15:22:12  124.99
# 1  7c67e1448b00f6e969d365cea6b010ab  2017-05-22 15:22:12  124.99
# 2  7c67e1448b00f6e969d365cea6b010ab  2017-05-22 15:22:12  124.99
# 3  7c67e1448b00f6e969d365cea6b010ab  2017-05-22 15:22:12  124.99
# 4  7c67e1448b00f6e969d365cea6b010ab  2017-05-22 15:22:12  124.99
#
#   freight_value  seller_zip_code_prefix      seller_city  seller_state
# 0         21.88                  8577.0  itaquaquecetuba            SP
# 1         21.88                  8577.0  itaquaquecetuba            SP
# 2         21.88                  8577.0  itaquaquecetuba            SP
# 3         21.88                  8577.0  itaquaquecetuba            SP
# 4         21.88                  8577.0  itaquaquecetuba            SP
#
# [5 rows x 39 columns]

# %%
all_df = all_df.drop_duplicates('order_id')

# %%
all_df.groupby(by='product_category_name_english').agg({
    'order_id': 'nunique',
    'review_score': ['min', 'max']
})
# Out:
#                               order_id review_score
#                                nunique          min  max
# product_category_name_english
# agro_industry_and_commerce         182          1.0  5.0
# air_conditioning                   251          1.0  5.0
# art                                198          1.0  5.0
# arts_and_craftmanship               22          1.0  5.0
# audio                              346          1.0  5.0
# ...                                ...          ...  ...
# stationery                        2292          1.0  5.0
# tablets_printing_image              79          1.0  5.0
# telephony                         4172          1.0  5.0
# toys                              3845          1.0  5.0
# watches_gifts                     5582          1.0  5.0
#
# [71 rows x 3 columns]

# %%
product_count = all_df.groupby('product_category_name_english').product_id.count().reset_index()
sorted_product = product_count.sort_values(by='product_id', ascending=False)

sorted_product
# Out:
#    product_category_name_english  product_id
# 7                 bed_bath_table        9314
# 43                 health_beauty        8774
# 65                sports_leisure        7664
# 15         computers_accessories        6649
# 39               furniture_decor        6332
# ..                           ...         ...
# 3          arts_and_craftmanship          22
# 52                    la_cuisine          12
# 11             cds_dvds_musicals          12
# 29     fashion_childrens_clothes           7
# 61         security_and_services           2
#
# [71 rows x 2 columns]

# %%
all_df.to_csv('all_data.csv', index=False)

# %% [markdown]
# ## **Data Visualizations**

# %% [markdown]
# ### What is the highest and lowest selling product?

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

colors = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(x="product_id", y="product_category_name_english", data=sorted_product.head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("products with the highest sales", loc="center", fontsize=18)
ax[0].tick_params(axis ='y', labelsize=15)

sns.barplot(x="product_id", y="product_category_name_english", data=sorted_product.sort_values(by="product_id", ascending=True).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("products with the lowest sales", loc="center", fontsize=18)
ax[1].tick_params(axis='y', labelsize=15)
plt.show()
# Out:
# /var/folders/bl/7q8_y6sx36z1bp3d55tj22s80000gn/T/ipykernel_36527/1850365743.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="product_id", y="product_category_name_english", data=sorted_product.head(5), palette=colors, ax=ax[0])
# /var/folders/bl/7q8_y6sx36z1bp3d55tj22s80000gn/T/ipykernel_36527/1850365743.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="product_id", y="product_category_name_english", data=sorted_product.sort_values(by="product_id", ascending=True).head(5), palette=colors, ax=ax[1])

# %%
delivery_status = all_df['order_status'].value_counts().sort_values(ascending=False)
delivery_status
# Out:
# order_status
# delivered      96214
# shipped         1100
# canceled         623
# unavailable      607
# invoiced         313
# processing       300
# created            4
# approved           2
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x=delivery_status.index, 
    y=delivery_status.values, 
    order=delivery_status.index,
    palette=colors
)

plt.title("Successful Delivery", fontsize=15)
plt.xlabel("Delivery status")
plt.ylabel("Count")
plt.xticks(fontsize=12)
plt.show()
# Out:
# /var/folders/bl/7q8_y6sx36z1bp3d55tj22s80000gn/T/ipykernel_36527/3751456113.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=delivery_status.index,
# /var/folders/bl/7q8_y6sx36z1bp3d55tj22s80000gn/T/ipykernel_36527/3751456113.py:2: UserWarning:
# The palette list has fewer values (5) than needed (8) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x=delivery_status.index,

# %%
all_df.head(5)
# Out:
#                           customer_id                customer_unique_id  \
# 0    06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 126  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 251  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 285  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 368  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#      customer_zip_code_prefix          customer_city customer_state  \
# 0                       14409                 franca             SP
# 126                      9790  sao bernardo do campo             SP
# 251                      1151              sao paulo             SP
# 285                      8775        mogi das cruzes             SP
# 368                     13056               campinas             SP
#
#                              order_id order_status order_purchase_timestamp  \
# 0    00e7ee1b050b8499577073aeb2a297a1    delivered      2017-05-16 15:05:35
# 126  29150127e6685892b6eab3eec79f59c7    delivered      2018-01-12 20:48:24
# 251  b2059ed67ce144a36e2aa97d2c9e9ad2    delivered      2018-05-19 16:07:45
# 285  951670f92359f4fe4a63112aa7306eba    delivered      2018-03-13 16:06:38
# 368  6b7d50bd145f6fc7f33cebabd7e49d0f    delivered      2018-07-29 09:51:30
#
#       order_approved_at order_delivered_carrier_date  ... product_photos_qty  \
# 0   2017-05-16 15:22:12          2017-05-23 10:47:57  ...                1.0
# 126 2018-01-12 20:58:32          2018-01-15 17:14:59  ...                3.0
# 251 2018-05-20 16:19:10          2018-06-11 14:31:00  ...                1.0
# 285 2018-03-13 17:29:19          2018-03-27 23:22:42  ...                1.0
# 368 2018-07-29 10:10:09          2018-07-30 15:16:00  ...                1.0
#
#     product_category_name_english  order_item_id  \
# 0                office_furniture            1.0
# 126                    housewares            1.0
# 251              office_furniture            1.0
# 285              office_furniture            1.0
# 368                  home_confort            1.0
#
#                             seller_id  shipping_limit_date   price  \
# 0    7c67e1448b00f6e969d365cea6b010ab  2017-05-22 15:22:12  124.99
# 126  b8bc237ba3788b23da09c0f1f3a3288c  2018-01-18 20:58:32  289.00
# 251  7c67e1448b00f6e969d365cea6b010ab  2018-06-05 16:19:10  139.94
# 285  7c67e1448b00f6e969d365cea6b010ab  2018-03-27 16:31:16  149.94
# 368  4a3ca9315b744ce9f8e9374361493884  2018-07-31 10:10:09  230.00
#
#     freight_value  seller_zip_code_prefix      seller_city  seller_state
# 0           21.88                  8577.0  itaquaquecetuba            SP
# 126         46.48                 88303.0           itajai            SC
# 251         17.79                  8577.0  itaquaquecetuba            SP
# 285         23.36                  8577.0  itaquaquecetuba            SP
# 368         22.25                 14940.0         ibitinga            SP
#
# [5 rows x 39 columns]

# %% [markdown]
# ### What location with the most customers?

# %%
customers_location = customer.merge(geolocation,left_on='customer_zip_code_prefix',right_on='geolocation_zip_code_prefix',how='inner')
customers_location.head(4)
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 2  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 3  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
#
#    customer_zip_code_prefix customer_city customer_state  \
# 0                     14409        franca             SP
# 1                     14409        franca             SP
# 2                     14409        franca             SP
# 3                     14409        franca             SP
#
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                        14409       -20.509897       -47.397866
# 1                        14409       -20.497396       -47.399241
# 2                        14409       -20.510459       -47.399553
# 3                        14409       -20.480940       -47.394161
#
#   geolocation_city geolocation_state
# 0           franca                SP
# 1           franca                SP
# 2           franca                SP
# 3           franca                SP

# %%
customers_location.duplicated().sum()
# Out:
# 0

# %%
brazil = mpimg.imread('brazil-map.jpeg')
ax = customers_location.plot(kind="scatter", x="geolocation_lng", y="geolocation_lat", figsize=(10,10), alpha=0.3,s=0.3,c='green')
plt.axis('off')
plt.imshow(brazil, extent=[-73.98283055, -33.8,-33.75116944,5.4])
plt.title('Location with the most customer')
plt.show()

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# ### 1. What is the most selling product?

# %% [markdown]
# Berdasarkan diagram di atas product bed_bath_table merupakan barang yang memiliki jumlah penjualan terbanyak, sedangkan product security_and_service merupakan kategori yang paling sedikit penjualannya

# %% [markdown]
# ### 2. How successful the delivery?

# %% [markdown]
# Berdasarkan diagram di atas hampir seluruh transaksi berhasil dilakukan hingga pada status 'Delivered' yang berarti barang telah sampai ke pada customer

# %% [markdown]
# ### 3. What location with the most customer?

# %% [markdown]
# Berdasarkan diagram di atas dapat dikatakan bahwa mayoritas pelanggan berasal dari daerah brazil bagian selatan
